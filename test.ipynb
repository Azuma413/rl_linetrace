# %%
from drqv2.my_simulator_v2 import MyEnv2
import matplotlib.pyplot as plt
import cv2
import numpy as np
env = MyEnv2()
dic = env.reset()
image0 = dic['observation'][0]
image1 = dic['observation'][1]
plt.imshow(image1)
# Out:
# obs_height 67.37831500277655

# %%
dic = env.step(1)
image = env.render()
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dic = env.step(1)
#       2 image = env.render()
#       3 plt.imshow(image)
#
# File e:\SourceCode\VScode\rl_linetrace\drqv2\my_simulator_v2.py:42, in MyEnv2.step(self, action)
#      40 done = False
#      41 self.count += 1 # ステップ数をカウント
# ---> 42 obs, reward = self.simulator.simulate(action[0]) # シミュレータを1ステップ進める
#      43 obs = obs.astype(np.float32) # 観測をfloat32に変換
#      44 # [64,64,2]->[2,64,64]
#
# TypeError: 'int' object is not subscriptable

# %%
plt.imshow(dic['observation'][1])
