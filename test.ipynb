# %%
from simulator import MySimulator
import numpy as np
from matplotlib import pyplot as plt

sim = MySimulator(init_pos=[278, 396])

# %%
action = np.array([0.0, 1.0])
obs, reward, is_in_area = sim.simulate(action)
view_image = sim.render()
plt.imshow(view_image)
# plt.imshow(obs, cmap='gray')
print(reward)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.46633290768186486

# %%
prior_pos = [-82, -4] #[278, 396]
robot_pos = [-82, 11] #[278, 411]
center = [0, 0] #[360, 400]
range = 80
theta1 = np.arctan2(robot_pos[1] - center[1], robot_pos[0] - center[0])
theta2 = np.arctan2(prior_pos[1] - center[1], prior_pos[0] - center[0])
if theta2 < 0:
    theta2 += 2*np.pi
print("theta1", theta1*180/np.pi)
print("theta2", theta2*180/np.pi)
length = range * (theta1 - theta2)
print(length)
# Out:
# theta1 172.35959323897325
# theta2 182.7927023657133
# -14.567368438518713
