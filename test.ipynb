# %%
from drqv2.my_simulator_v2 import MyEnv2
import matplotlib.pyplot as plt
import cv2
import numpy as np
env = MyEnv2()
dic = env.reset()
image0 = dic['observation'][0]
image1 = dic['observation'][1]
plt.imshow(image1)
# Out:
# theta:0.0

# %%
dic = env.step(np.array([0.5]))
image = env.render()
plt.imshow(image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# theta:225.00000000000006

# %%
plt.imshow(dic['observation'][1])
